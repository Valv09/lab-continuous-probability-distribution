# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from scipy.stats import uniform

from scipy.stats import norm

from scipy.stats import expon

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.08655007 2.60644814 2.98962645 2.16171383 2.00087891 2.2338515
#  2.26198937 2.43144641 2.30382817 2.47350871]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# your code here
def u_r_n(bottom, ceiling, count):
    return uniform.rvs(size=count, loc=bottom, scale =(ceiling-bottom))

# %%
u_r_n(10, 15, 100)
# Out:
# array([13.69118775, 11.71807984, 14.82082538, 14.72250294, 10.79808694,
#        13.70249389, 14.12543646, 12.9648957 , 14.02300134, 12.51250808,
#        13.5432796 , 11.31165992, 14.78149899, 11.49917839, 14.95521983,
#        12.62202131, 13.42117592, 12.90179095, 14.67952155, 11.71299008,
#        13.05626753, 10.89386786, 11.79052698, 12.5846649 , 10.11943544,
#        14.6101093 , 10.46044722, 14.01358293, 14.48204489, 14.41407699,
#        12.47371993, 14.69826741, 13.09131549, 13.49952132, 13.62605758,
#        14.7506258 , 11.8359231 , 13.84926045, 10.52146904, 10.51892481,
#        12.28168138, 14.91856809, 12.38060969, 13.84177977, 13.48112936,
#        10.6241524 , 11.44544693, 14.90309026, 13.980326  , 14.92611448,
#        13.35577419, 11.62244095, 14.28441805, 12.99832612, 10.33281115,
#        10.16472471, 11.31244818, 11.05006514, 14.44233035, 11.26188724,
#        11.0063827 , 10.98489774, 14.47837886, 14.87119951, 11.01751533,
# ...

# %%
u_r_n(10, 60, 1000)
# Out:
# array([23.4599559 , 13.3793731 , 40.07127509, 38.35567197, 10.82929995,
#        12.35664421, 11.81307609, 29.2040037 , 30.47433304, 34.8727779 ,
#        48.02376647, 43.22619571, 32.27067029, 35.53167095, 58.95634594,
#        20.5177265 , 59.38064821, 33.11759032, 38.66719391, 17.70028212,
#        16.86956028, 37.22230305, 41.34568624, 23.50356257, 41.41155365,
#        22.44448559, 40.90776811, 36.66696315, 28.26714643, 16.14345461,
#        46.74563682, 20.01634259, 46.39085974, 57.35675548, 45.74254149,
#        51.04979359, 25.4859489 , 38.41309818, 59.73187432, 23.06289386,
#        20.77713142, 57.98263218, 50.54887781, 16.49558619, 55.1207065 ,
#        23.91887348, 30.78071904, 36.30728824, 28.74728125, 33.45595878,
#        45.27324902, 29.54786183, 50.22618888, 13.37630118, 27.50687406,
#        34.01145357, 44.56817331, 19.99233154, 36.66247741, 15.72831871,
#        18.73428716, 16.01728568, 33.23897058, 38.60770121, 13.0542976 ,
# ...

# %%
fig, axis = plt.subplots(1, 2, sharey=True)

axis[0].hist(u_r_n(bottom=10, ceiling=15, count=100))

axis[1].hist(u_r_n(bottom=10, ceiling=60, count=1000));

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
# your code here
def nrn(avg, std, count):
    return norm.rvs(avg, std, count)

# %%
nrn(100, 1, 1000)
# Out:
# array([ 99.01549375,  98.81065826,  98.84167673,  99.74224814,
#        100.66717821, 100.02122456,  99.99938772, 100.23894278,
#        101.49590326, 100.58857106,  98.81022977, 100.75785698,
#         98.52847703,  98.60395922,  99.13416889, 100.70726689,
#        100.57027631, 101.16511348,  99.71653621,  98.36610883,
#        101.57191888,  98.67265324, 101.17106364,  99.24663133,
#         99.68194955, 100.6199315 ,  99.78613995, 101.49960381,
#         98.57510088,  98.52942768,  99.02970861,  99.13127833,
#        100.5026518 ,  99.80588198,  99.12164546,  99.6028319 ,
#        100.93762436,  99.84647481,  99.44342596, 100.06802596,
#        100.82448955,  99.16239062,  99.5153076 , 100.10405361,
#         99.51340696,  99.57877735, 100.31487517, 100.31490286,
#        101.06948251,  99.33091754, 101.14734218,  99.00884166,
#         99.92798716, 100.5897956 ,  99.95458063,  99.40047108,
#        100.52752299,  99.30236473, 100.55671832,  99.03364353,
# ...

# %%
nrn(100, 50, 1000)
# Out:
# array([121.0318745 ,  85.33732836, 108.34115306, 213.65960746,
#        135.03392925, 154.27529426,  80.7795007 ,  94.13248959,
#         30.50664681,  34.83503852, 115.42883562, 147.35708106,
#         86.26026647,  84.40876347, 128.9397696 ,  62.40543096,
#         73.16539063,  54.96926549,  99.89341442,  94.9723968 ,
#         68.72217301, 106.94091638, 112.05508085, 169.22437289,
#        140.54537094, 173.19965801,  95.35024078, 129.97332004,
#         34.39921725,  66.44707889, 240.59401663,  80.73756786,
#         97.4790062 , 179.82595386,  96.28601356,  65.20067328,
#         37.42680118, 119.12627183,  98.73171092,  37.93021056,
#        199.2186378 ,  97.33365334, 166.11790677, 148.75757692,
#        151.04969661, 199.6926003 ,  36.62505166,  67.91028908,
#        116.85098245, 116.3487505 ,  85.6432222 ,  65.31085844,
#         68.34654517, 202.17405396, 154.52142105,  77.24202841,
#        167.50471561,  75.14350293,  45.9359751 , 137.68497018,
# ...

# %%
fig, axis = plt.subplots(1, 2, sharey=True)

axis[0].hist(nrn(10, 1, 1000), bins=50)

axis[1].hist(nrn(10, 50, 1000),bins=50);

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %%
df = pd.read_csv('vehicles.csv')
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
# your code here
plt.hist(df['Fuel Barrels/Year'], bins=50);

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
# your code here
plt.hist(df['CO2 Emission Grams/Mile'], bins=50);

# %% [markdown]
# 3. Combined MPG

# %%
# your code here
plt.hist(df['Combined MPG'], bins=50);

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# your answer here
me pare que combined MPG, tiene la forma de una distribucion normal aunque con algunos valores extremos

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 1 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# your code here
def ern(mean, size):
    return np.random.exponential(mean, size)

# %%
fig, axis = plt.subplots(1, 2, sharey=True)

axis[0].hist(ern(1, 1000), bins=50)

axis[1].hist(ern(100, 1000), bins=50);

# %% [markdown]
# How are the two distributions different?

# %%
# your answer here
no hay muchas doferencias a simple vista

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your answer here
# Hint: This is same as saying P(x<15)
expon.cdf(14.99, scale=10)
# Out:
# 0.776646598089144

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your answer here
1 - expon.cdf(14.99, scale=10)
# Out:
# 0.22335340191085595
